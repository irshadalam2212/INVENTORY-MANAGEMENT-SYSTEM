# %%
record = { 201 : {'prod_name' : 'Parle G', 'price': 5 , 'mfg_date' : '25-07-2021' , 'exp_date' : '25-01-2023' , 'category' : 'biscuit' , 'stock' : 1000},
           202 : {'prod_name' : 'bourbon', 'price': 10 , 'mfg_date' : '02-12-2020' , 'exp_date' : '12-01-2022', 'category' : 'chocolate', 'stock' : 800},
           203 : {'prod_name' : '5 star', 'price': 5 , 'mfg_date' : '17-05-2021' , 'exp_date' : '19-05-2022' , 'category' : 'chocolate' , 'stock' : 665},
           204 : {'prod_name' : 'parles', 'price': 10 , 'mfg_date' : '05-01-2021' , 'exp_date' : '25-01-2022' , 'category' : 'wafer' , 'stock' : 687},
           205 : {'prod_name' : 'Marie Gold', 'price': 10 , 'mfg_date' : '08-07-2020' , 'exp_date' : '25-01-2022' , 'category' : 'biscuit' , 'stock' : 2235},
           206 : {'prod_name' : 'Crack Jack', 'price': 10 , 'mfg_date' : '25-12-2020' , 'exp_date' : '25-01-2022' , 'category' : 'biscuit' , 'stock' : 1600},
           207 : {'prod_name' : 'Bounce', 'price': 5 , 'mfg_date' : '15-08-2021' , 'exp_date' : '25-01-2023' , 'category' : 'biscuit' , 'stock' : 900},
           208 : {'prod_name' : 'Dairy Milk', 'price': 5 , 'mfg_date' : '05-09-2020' , 'exp_date' : '05-03-2022' , 'category' : 'chocolate' , 'stock' : 250},
           209 : {'prod_name' : 'Munch', 'price': 10 , 'mfg_date' : '25-02-2021' , 'exp_date' : '15-01-2022' , 'category' : 'chocolate' , 'stock' : 990},
           210 : {'prod_name' : 'Lunch Box', 'price': 5 , 'mfg_date' : '05-06-2021' , 'exp_date' : '25-09-2021' , 'category' : 'snacks' , 'stock' : 1235},
           211 : {'prod_name' : 'Moong daal', 'price': 5 , 'mfg_date' : '25-07-2019' , 'exp_date' : '25-01-2022' , 'category' : 'snacks' , 'stock' : 200},
           212 : {'prod_name' : 'Bhujiya', 'price': 5 , 'mfg_date' : '02-12-2021' , 'exp_date' : '12-01-2022', 'category' : 'snacks', 'stock' : 867},
           213 : {'prod_name' : 'Fevicol', 'price': 10 , 'mfg_date' : '17-05-2021' , 'exp_date' : '19-05-2023' , 'category' : 'stationary' , 'stock' : 95},
           214 : {'prod_name' : 'Dairy Milk Silk', 'price': 140 , 'mfg_date' : '15-05-2021' , 'exp_date' : '25-11-2021' , 'category' : 'chocolate' , 'stock' : 87},
           215 : {'prod_name' : 'kurkure', 'price': 5 , 'mfg_date' : '08-07-2020' , 'exp_date' : '25-01-2021' , 'category' : 'snacks' , 'stock' : 225},
           216 : {'prod_name' : 'Butter Scotch', 'price': 40 , 'mfg_date' : '25-12-2020' , 'exp_date' : '25-01-2021' , 'category' : 'icecream' , 'stock' : 105},
           217 : {'prod_name' : 'Vanilla', 'price': 20 , 'mfg_date' : '15-05-2021' , 'exp_date' : '25-08-2021' , 'category' : 'icecream' , 'stock' : 785},
           218 : {'prod_name' : 'choco pie', 'price': 10 , 'mfg_date' : '05-09-2021' , 'exp_date' : '05-03-2022' , 'category' : 'cake' , 'stock' : 277},
           219 : {'prod_name' : 'snackers', 'price': 5 , 'mfg_date' : '25-02-2021' , 'exp_date' : '15-01-2022' , 'category' : 'chocolate' , 'stock' : 90},
           220 : {'prod_name' : 'crispello', 'price': 10 , 'mfg_date' : '05-06-2022' , 'exp_date' : '25-09-2023' , 'category' : 'chocolate' , 'stock' : 125},
           221 : {'prod_name' : 'sprite', 'price': 45 , 'mfg_date' : '25-07-2021' , 'exp_date' : '25-01-2022' , 'category' : 'drink' , 'stock' : 550},
           222 : {'prod_name' : 'Coca cola', 'price': 65 , 'mfg_date' : '02-12-2020' , 'exp_date' : '12-06-2021', 'category' : 'drink', 'stock' : 80},
           223 : {'prod_name' : 'Mazaa', 'price': 95 , 'mfg_date' : '17-05-2021' , 'exp_date' : '19-02-2022' , 'category' : 'drink' , 'stock' : 65},
           224 : {'prod_name' : 'Limica', 'price': 35 , 'mfg_date' : '05-01-2021' , 'exp_date' : '25-07-2021' , 'category' : 'drink' , 'stock' : 68},
           225 : {'prod_name' : 'Mlky bar', 'price': 10 , 'mfg_date' : '08-07-2021' , 'exp_date' : '25-01-2022' , 'category' : 'chocolate' , 'stock' : 225},
           226 : {'prod_name' : 'Fanta', 'price': 65 , 'mfg_date' : '25-08-2021' , 'exp_date' : '05-02-2022' , 'category' : 'drink' , 'stock' : 600},
           227 : {'prod_name' : 'Thums up', 'price': 45 , 'mfg_date' : '15-08-2021' , 'exp_date' : '25-03-2022' , 'category' : 'drink' , 'stock' : 90},
           228 : {'prod_name' : 'Kuch Kuch', 'price': 5 , 'mfg_date' : '05-09-2020' , 'exp_date' : '05-03-2022' , 'category' : 'snacks' , 'stock' : 50},
           229 : {'prod_name' : 'Monacco', 'price': 10 , 'mfg_date' : '18-02-2021' , 'exp_date' : '15-01-2022' , 'category' : 'Biscuit' , 'stock' : 90},
           230 : {'prod_name' : 'Britania Rusk', 'price': 10 , 'mfg_date' : '05-06-2021' , 'exp_date' : '25-09-2021' , 'category' : 'Biscuit' , 'stock' : 125}}

# %%
record
# Out:
# {201: {'prod_name': 'Parle G',
#   'price': 5,
#   'mfg_date': '25-07-2021',
#   'exp_date': '25-01-2023',
#   'category': 'biscuit',
#   'stock': 1000},
#  202: {'prod_name': 'bourbon',
#   'price': 10,
#   'mfg_date': '02-12-2020',
#   'exp_date': '12-01-2022',
#   'category': 'chocolate',
#   'stock': 800},
#  203: {'prod_name': '5 star',
#   'price': 5,
#   'mfg_date': '17-05-2021',
#   'exp_date': '19-05-2022',
#   'category': 'chocolate',
#   'stock': 665},
#  204: {'prod_name': 'parles',
#   'price': 10,
#   'mfg_date': '05-01-2021',
#   'exp_date': '25-01-2022',
#   'category': 'wafer',
#   'stock': 687},
#  205: {'prod_name': 'Marie Gold',
#   'price': 10,
#   'mfg_date': '08-07-2020',
#   'exp_date': '25-01-2022',
#   'category': 'biscuit',
#   'stock': 2235},
#  206: {'prod_name': 'Crack Jack',
#   'price': 10,
#   'mfg_date': '25-12-2020',
#   'exp_date': '25-01-2022',
#   'category': 'biscuit',
#   'stock': 1600},
#  207: {'prod_name': 'Bounce',
#   'price': 5,
# ...

# %%
import json
js = json.dumps(record)

# %%
js
# Out:
# '{"201": {"prod_name": "Parle G", "price": 5, "mfg_date": "25-07-2021", "exp_date": "25-01-2023", "category": "biscuit", "stock": 1000}, "202": {"prod_name": "bourbon", "price": 10, "mfg_date": "02-12-2020", "exp_date": "12-01-2022", "category": "chocolate", "stock": 800}, "203": {"prod_name": "5 star", "price": 5, "mfg_date": "17-05-2021", "exp_date": "19-05-2022", "category": "chocolate", "stock": 665}, "204": {"prod_name": "parles", "price": 10, "mfg_date": "05-01-2021", "exp_date": "25-01-2022", "category": "wafer", "stock": 687}, "205": {"prod_name": "Marie Gold", "price": 10, "mfg_date": "08-07-2020", "exp_date": "25-01-2022", "category": "biscuit", "stock": 2235}, "206": {"prod_name": "Crack Jack", "price": 10, "mfg_date": "25-12-2020", "exp_date": "25-01-2022", "category": "biscuit", "stock": 1600}, "207": {"prod_name": "Bounce", "price": 5, "mfg_date": "15-08-2021", "exp_date": "25-01-2023", "category": "biscuit", "stock": 900}, "208": {"prod_name": "Dairy Milk", "price": 5,
# ...

# %%
fd = open("record.json" , "w")

fd.write(js)

fd.close()

# %%
fd = open ("record.json" , "r")
record_2 = fd.read()
fd.close()

# %%
record2 = json.dumps("record.json")

# %%
import time
lst = []

print('*****************************************************************')
print("*********************Inventory management system*****************")

print('_________________________________________________________________') 

print (time.ctime())
print('_________________________________________________________________')


cust_input = int(input ("Enter the number of products : "))

for i in range(cust_input):
    prod_id = int(input("Enter The Product ID : "))
    prod_quan = int(input("Enter The Quantity Of Product : "))
    
    if prod_id in record.keys() :
        print("ID of the product : " , prod_id)
        print("Name of the Product : " , record[prod_id]["prod_name"])
        print("Price of The Product : " ,record[prod_id]["price"])
        print("Manufacturing date of The Product : " ,record[prod_id]["mfg_date"])
        print("Expiry date of The Product : " ,record[prod_id]["exp_date"])
        print("Category of The Product : " ,record[prod_id]["category"])
        print("Quantity of The Product : " ,prod_quan)
    
        record[prod_id]["stock"] = record[prod_id]["stock"] - prod_quan
    
        Amount = record[prod_id]["price"] * prod_quan
    
        print ("**************************************************************")
    
        print("Amount of the product : " , Amount)
    
        print ("**************************************************************")
    
        lst.append(Amount)
    
    
    else :
        print("***************************************************************")
        print("Invalid Product ID")
        print("***************************************************************")
    
    
print ("Sub Total : " , sum(lst))
print ("**************************************************************")
print ("THANK YOU")
print ("VISIT AGAIN")

print ("______________________________________________________________")
# Out:
# *****************************************************************
# *********************Inventory management system*****************
# _________________________________________________________________
# Fri Sep  3 15:18:34 2021
# _________________________________________________________________
# Enter the number of products : 3
# Enter The Product ID : 225
# Enter The Quantity Of Product : 5
# ID of the product :  225
# Name of the Product :  Mlky bar
# Price of The Product :  10
# Manufacturing date of The Product :  08-07-2021
# Expiry date of The Product :  25-01-2022
# Category of The Product :  chocolate
# Quantity of The Product :  5
# **************************************************************
# Amount of the product :  50
# **************************************************************
# Enter The Product ID : 228
# Enter The Quantity Of Product : 4
# ID of the product :  228
# Name of the Product :  Kuch Kuch
# Price of The Product :  5
# ...
